# %%
import yfinance as yf

# %%
stock = yf.Ticker("ITSA4.SA")
df = stock.history(period="7d",  interval = "1m")

# %%
df
# Out:
#                            Open  High   Low  Close  Volume  Dividends  \
# Datetime
# 2022-12-12 10:03:00-03:00  8.16  8.16  8.12   8.12       0          0
# 2022-12-12 10:04:00-03:00  8.14  8.15  8.10   8.10   52500          0
# 2022-12-12 10:05:00-03:00  8.10  8.15  8.10   8.15   52800          0
# 2022-12-12 10:06:00-03:00  8.15  8.15  8.15   8.15   25900          0
# 2022-12-12 10:07:00-03:00  8.15  8.20  8.15   8.20   63100          0
# ...                         ...   ...   ...    ...     ...        ...
# 2022-12-20 10:59:00-03:00  8.46  8.47  8.46   8.47    6800          0
# 2022-12-20 11:00:00-03:00  8.47  8.48  8.46   8.47   65100          0
# 2022-12-20 11:01:00-03:00  8.48  8.48  8.46   8.48    6800          0
# 2022-12-20 11:02:00-03:00  8.48  8.48  8.47   8.48    3200          0
# 2022-12-20 11:03:12-03:00  8.48  8.48  8.48   8.48       0          0
#
#                            Stock Splits
# Datetime
# 2022-12-12 10:03:00-03:00             0
# ...

# %%
info = stock.get_info()
info
# Out:
# {'regularMarketPrice': None,
#  'preMarketPrice': None,
#  'logo_url': '',
#  'trailingPegRatio': None}
